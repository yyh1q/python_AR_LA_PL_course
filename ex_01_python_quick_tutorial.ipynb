# %%
print('Hello python!') #打印字符串
print("Hello world!")
print("_"*50)
print("我有一所房子，面朝大海，春暖花开。")
print("Life is just like this.")
# Out:
# Hello python!
# Hello world!
# __________________________________________________
# 我有一所房子，面朝大海，春暖花开。
# Life is just like this.

# %%
print("加：",3+9) #打印简单的运算
print("减：",39-18)
print("乘：",3*38)
print("除：", 14/3)
print("整除：", 6//2)
print("余数：", 98%2)
print("幂：",2**64)
# Out:
# 加： 12
# 减： 21
# 乘： 114
# 除： 4.666666666666667
# 整除： 3
# 余数： 0
# 幂： 18446744073709551616

# %%
x=8.0
monadic_equation=2*x+1
print("monadic_equation=",monadic_equation)
print("monadic_equation=%.2f"%monadic_equation) #%字符串格式化方法
print("monadic_equation={:.2f}".format(monadic_equation)) #format()字符串格式化方法
# Out:
# monadic_equation= 17.0
# monadic_equation=17.00
# monadic_equation=17.00

# %%
city_name="Ying chuan"
coordinate_longitude=160.942292
coordiante_latitude=50.261013
print("The longitude of the Ying chuan coordinate is {lon:.2f}, and the latitude is {lat}.".format(lon=coordinate_longitude,lat=coordiante_latitude))
# Out:
# The longitude of the Ying chuan coordinate is 160.94, and the latitude is 50.261013.

# %%
a,m,b=4,8,1。
func_2=2*a+3*m+b
print("func_2={}".format(x,y,b,func_2))
# Out:
#   File "C:\Users\Dell\AppData\Local\Temp/ipykernel_14088/2182105869.py", line 1
#     a,m,b=4,8,1。
#                ^
# SyntaxError: invalid character '。' (U+3002)

# %%
lst_n=list(range(8,15,1)) #建立列表。range(start,stop,[,step])建立区间。
print(lst_n)
print("列表长={}".format(len(lst_n)))
print("Maximum 价值={}".format(max(lst_n)))
print("Minimum 价值={}".format(min(lst_n)))
# Out:
# [8, 9, 10, 11, 12, 13, 14]
# 列表长=7
# Maximum 价值=14
# Minimum 价值=8

# %%
lst_s=list(map(chr,range(80,110)))
print(lst_s)
print("_"*50)
print("[3:6]->{}".format(lst_s[3:6]))
print("[-3:-1]->{}".format(lst_s[-3:-1]))
print("[-3:]->{}".format(lst_s[-3:]))
print("[:3]->{}".format(lst_s[:3]))
print("[:]->{}".format(lst_s[:]))
# Out:
# ['P', 'Q', 'R', 'S', 'T', 'U', 'V', 'W', 'X', 'Y', 'Z', '[', '\\', ']', '^', '_', '`', 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm']
# __________________________________________________
# [3:6]->['S', 'T', 'U']
# [-3:-1]->['k', 'l']
# [-3:]->['k', 'l', 'm']
# [:3]->['P', 'Q', 'R']
# [:]->['P', 'Q', 'R', 'S', 'T', 'U', 'V', 'W', 'X', 'Y', 'Z', '[', '\\', ']', '^', '_', '`', 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm']

# %%
lst_s=list(range(8,15,1))
print(lst_s)
print("_"*50)
print("[0:10:2]->{}".format(lst_s[6:1:8]))
print("[::3]->{}".format(lst_s[8:9:3]))
print("[9:3:-2]->{}".format(lst_s[9:3:-2]))
print("[20:3:-2]->{}".format(lst_s[2:8:-9]))
print("[7::-2]->{}".format(lst_s[7::-2]))
print("[:3:-2]->{}".format(lst_s[:3:-7]))
# Out:
# [8, 9, 10, 11, 12, 13, 14]
# __________________________________________________
# [0:10:2]->[]
# [::3]->[]
# [9:3:-2]->[14, 12]
# [20:3:-2]->[]
# [7::-2]->[14, 12, 10, 8]
# [:3:-2]->[14]

# %%
lst_s=list(range(8,6,1))
print(lst_s)
print("_"*50)
lst_s[5]=90#元素赋值
print("lst_s[5]=99->{}".format(lst_s))
lst_none=lst_s+[None]*6
print("lst_s+[None]*6->{}".format(lst_none))
lst_none[13]=190
print("lst_none[13]=2015->{}".format(lst_none))
lst_none[-6:-3]=list(range(10,104,2))#分片赋值
print("lst_none[-6:-3]=list(range(852,04,2))->{}".format(lst_none))
lst_none[1:1]=[0,0,0,99]
print("lst_none[1:1]=[0,0,0,12]->{}".format(lst_none))
del lst_none[-2:]#删除元素
print("del lst_none[-2:]->{}".format(lst_none))
# Out:
# []
# __________________________________________________
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8508/1212106734.py in <module>
#       2 print(lst_s)
#       3 print("_"*50)
# ----> 4 lst_s[5]=90#元素赋值
#       5 print("lst_s[5]=99->{}".format(lst_s))
#       6 lst_none=lst_s+[None]*6
#
# IndexError: list assignment index out of range

# %%
lst_s_2=list(map(chr,range(100,105)))
print(lst_s_2)
print("_"*50)
lst_s_2.append(99)
print("lst_s_2.append(99)->{}".format(lst_s_2))
lst_s_2.append(list(range(78,200,5)))
print("lst_s_2.append(list(range(50,80,5)))->{}".format(lst_s_2))
lst_spechars=['*',')','*']
lst_s_2.extend(lst_spechars)
print("lst_s_2.extend(lst_spechars)->{}".format(lst_s_2))
print("lst_s_2.count('*')={}".format(lst_s_2.count('*')))
print("lst_s_2.index('e')={}".format(lst_s_2.index('e')))
lst_s_2.insert(2,[1000,1200,1500])
print("lst_s_2.insert(2,[1000,1200,140])->{}".format(lst_s_2))
print("lst_s_2.pop(7)_popup->{}".format(lst_s_2.pop(7)))
print("lst_s_2.pop(7)_retention->{}".format(lst_s_2))
lst_s_2.remove('*')
print("lst_s_2.remove('*')_retention->{}".format(lst_s_2))
list_n_2=[2,42,6,95,4,3]
list_n_2.sort()
print("list_n_2.sort()->{}".format(list_n_2))
# Out:
# ['d', 'e', 'f', 'g', 'h']
# __________________________________________________
# lst_s_2.append(99)->['d', 'e', 'f', 'g', 'h', 99]
# lst_s_2.append(list(range(50,80,5)))->['d', 'e', 'f', 'g', 'h', 99, [78, 83, 88, 93, 98, 103, 108, 113, 118, 123, 128, 133, 138, 143, 148, 153, 158, 163, 168, 173, 178, 183, 188, 193, 198]]
# lst_s_2.extend(lst_spechars)->['d', 'e', 'f', 'g', 'h', 99, [78, 83, 88, 93, 98, 103, 108, 113, 118, 123, 128, 133, 138, 143, 148, 153, 158, 163, 168, 173, 178, 183, 188, 193, 198], '*', ')', '*']
# lst_s_2.count('*')=2
# lst_s_2.index('e')=1
# lst_s_2.insert(2,[1000,1200,140])->['d', 'e', [1000, 1200, 1500], 'f', 'g', 'h', 99, [78, 83, 88, 93, 98, 103, 108, 113, 118, 123, 128, 133, 138, 143, 148, 153, 158, 163, 168, 173, 178, 183, 188, 193, 198], '*', ')', '*']
# lst_s_2.pop(7)_popup->[78, 83, 88, 93, 98, 103, 108, 113, 118, 123, 128, 133, 138, 143, 148, 153, 158, 163, 168, 173, 178, 183, 188, 193, 198]
# lst_s_2.pop(7)_retention->['d', 'e', [1000, 1200, 1500], 'f', 'g', 'h', 99, '*', ')', '*']
# lst_s_2.remove('*')_retention->['d', 'e', [1000, 1200, 1500], 'f', 'g', 'h', 99, ')', '*']
# list_n_2.sort()->[2, 3, 4, 6, 42, 95]

# %%
tuple_1=2,3,5,
print("tuple_1=2,3,5,->{}".format(tuple_1))
print("9*(200*6,)->{}".format(9*(200*9,)))
print("tuple((5,8,9))->{}".format(tuple((4,6,7)))) #用()
print("tuple([5,8,9])->{}".format(tuple([4,6,7]))) #用[]
# Out:
# tuple_1=2,3,5,->(2, 3, 5)
# 9*(200*6,)->(1800, 1800, 1800, 1800, 1800, 1800, 1800, 1800, 1800)
# tuple((5,8,9))->(4, 6, 7)
# tuple([5,8,9])->(4, 6, 7)

# %%
import random
items=[(0,[i for i in range(5)]),(1,[random.sample(list(range(620,540,2)),3)]),(2,'python')]
print("items->{}".format(items))
dic=dict(items)
print("dic=dict(items)->{}".format(dic))
print("dic[1]->{}".format(dic[1]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8508/1907999173.py in <module>
#       1 import random
# ----> 2 items=[(0,[i for i in range(5)]),(1,[random.sample(list(range(620,540,2)),3)]),(2,'python')]
#       3 print("items->{}".format(items))
#       4 dic=dict(items)
#       5 print("dic=dict(items)->{}".format(dic))
#
# E:\kjkj\lib\random.py in sample(self, population, k, counts)
#     447         randbelow = self._randbelow
#     448         if not 0 <= k <= n:
# --> 449             raise ValueError("Sample larger than population or is negative")
#     450         result = [None] * k
#     451         setsize = 21        # size of a small set minus size of an empty list
#
# ValueError: Sample larger than population or is negative

# %%
print("len(dic)->{}".format(len(dic)))
dic[3]=(random.random(),random.uniform(200,300))
print("dic[3]=(random.random(),random.uniform(200,300))->{}".format(dic))
del dic[1]
print("del dic[1]->{}".format(dic))
print("3 in dic->{}".format(3 in dic))
print("5 in dic->{}".format(5 in dic))
print("dic.keys()->{}".format(dic.keys())) #应该放在字典的方法一节里
print("dic.values()->{}".format(dic.values()))
print("dic.items()->{}".format(dic.items()))
print("_"*50)
print("list(dic.keys())->{}".format(list(dic.keys())))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8508/592484541.py in <module>
# ----> 1 print("len(dic)->{}".format(len(dic)))
#       2 dic[3]=(random.random(),random.uniform(200,300))
#       3 print("dic[3]=(random.random(),random.uniform(200,300))->{}".format(dic))
#       4 del dic[1]
#       5 print("del dic[1]->{}".format(dic))
#
# NameError: name 'dic' is not defined

# %%
lst_s=list(map(chr,range(65,75)))
print(lst_s)
lst_s[4]=36
print("lst_s[4]=36->{}".format(lst_s))
lst_none=lst_s+[None]*3
print("lst_s+[None]*3->{}".format(lst_none))
lst_none[-2:]=list(range(50,105,2))
print("lst_none[-2:]=list(range(100,15,2))->{}".format(lst_none))
lst_none[1:1]=[0,0,0,200]
print("lst_none[1:1]=[0,1,0,12]->{}".format(lst_none))
del lst_none[-2:]
print("del lst_none[-2:]->{}".format(lst_none))
print("_"*50)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']
# lst_s[4]=36->['A', 'B', 'C', 'D', 36, 'F', 'G', 'H', 'I', 'J']
# lst_s+[None]*3->['A', 'B', 'C', 'D', 36, 'F', 'G', 'H', 'I', 'J', None, None, None]
# lst_none[-2:]=list(range(100,15,2))->['A', 'B', 'C', 'D', 36, 'F', 'G', 'H', 'I', 'J', None, 50, 52, 54, 56, 58, 60, 62, 64, 66, 68, 70, 72, 74, 76, 78, 80, 82, 84, 86, 88, 90, 92, 94, 96, 98, 100, 102, 104]
# lst_none[1:1]=[0,1,0,12]->['A', 0, 0, 0, 200, 'B', 'C', 'D', 36, 'F', 'G', 'H', 'I', 'J', None, 50, 52, 54, 56, 58, 60, 62, 64, 66, 68, 70, 72, 74, 76, 78, 80, 82, 84, 86, 88, 90, 92, 94, 96, 98, 100, 102, 104]
# del lst_none[-2:]->['A', 0, 0, 0, 200, 'B', 'C', 'D', 36, 'F', 'G', 'H', 'I', 'J', None, 50, 52, 54, 56, 58, 60, 62, 64, 66, 68, 70, 72, 74, 76, 78, 80, 82, 84, 86, 88, 90, 92, 94, 96, 98, 100]
# __________________________________________________

# %%
lst_s_3=list("i don't know what to do")
print("lst_s_3=list(\"i don't know what to do\")->{}".format(lst_s_3)) #"\" escape character
print("\"i don't know\"+\" what to do\"->{}".format("i don't know"+"what to do"))
print("\"+\".join(str(123456))->{}".format("+".join(str(123456))))
print("len(\"i don't know what to do\")->{}".format(len("i don't know what to do")))
coordinates="124.823608,45.118243"
print("coordinates.split(\",\")->{}".format(coordinates.split(",")))
print("eval(coordinates)->{}".format(eval(coordinates)))
print("\"i don't know what to do\".lower()->{}".format("i don't know what to do".lower()))
print("\"i don't know what to do\".upper()->{}".format("i don't know what to do".upper()))
print("\"i don't know what to do\"[6:]->{}".format("i don't know what to do"[6:]))
print("\"i don't know what to do\".strip()->{}".format("i don't know what to do".strip()))
print("\"i don't know what to do\".replace(\"a\",\"b\")->{}".format("i don't know what to do".replace("a","b")))
hello_lst=list("i don't know what to do")
hello_lst.sort()
print("hello_lst.sort()>{}".format(hello_lst))
print("\"i don't know what to do\".find(\"o\")->{}".format("i don't know what to do".find("o")))
print("_"*50)

format_str="%s and %s"
values=("xiaoming","xiaohong")
new_str=format_str % values
print("new_str=format_str % values->{}".format(new_str))
format_str_2="Pi with three decimals:%.4f,and enter a value with percent sign:%.1f %%"
from math import pi
new_str_2=format_str_2 % (pi,2.73)
print("new_str_2=format_str_2 % (pi,2.73)->{}".format(new_str_2))
print("_"*50)
# Out:
# lst_s_3=list("i don't know what to do")->['i', ' ', 'd', 'o', 'n', "'", 't', ' ', 'k', 'n', 'o', 'w', ' ', 'w', 'h', 'a', 't', ' ', 't', 'o', ' ', 'd', 'o']
# "i don't know"+" what to do"->i don't knowwhat to do
# "+".join(str(123456))->1+2+3+4+5+6
# len("i don't know what to do")->23
# coordinates.split(",")->['124.823608', '45.118243']
# eval(coordinates)->(124.823608, 45.118243)
# "i don't know what to do".lower()->i don't know what to do
# "i don't know what to do".upper()->I DON'T KNOW WHAT TO DO
# "i don't know what to do"[6:]->t know what to do
# "i don't know what to do".strip()->i don't know what to do
# "i don't know what to do".replace("a","b")->i don't know whbt to do
# hello_lst.sort()>[' ', ' ', ' ', ' ', ' ', "'", 'a', 'd', 'd', 'h', 'i', 'k', 'n', 'n', 'o', 'o', 'o', 'o', 't', 't', 't', 'w', 'w']
# "i don't know what to do".find("o")->3
# __________________________________________________
# new_str=format_str % values->xiaoming and xiaohong
# new_str_2=format_str_2 % (pi,2.73)->Pi with three decimals:3.1416,and enter a value with percent sign:2.7 %
# __________________________________________________

# %%
format_str="bye,%s and %s!"
values=("world","my dear")
new_str=format_str % values
print("new_str=format_str % values->{}".format(new_str))

format_str_2="Pi with three decimals:%.3f,and enter a value with percent sign:%.2f %%" #如果字符串里包含实际的%，则通过%%即两个百分号进行转义

from math import pi
new_str_2=format_str_2 % (pi,3.1415926)
print("new_str_2=format_str_2 % (pi,3.1415926)->{}".format(new_str_2))
# Out:
# new_str=format_str % values->bye,world and my dear!
# new_str_2=format_str_2 % (pi,3.1415926)->Pi with three decimals:3.142,and enter a value with percent sign:3.14 %

# %%
from string import Template
s_template_1=Template("$x,baoruiqin,$x!")
s_1=s_template_1.substitute(x="NB")
print("s_1=s_template_1.substitute(x=\"NB\")->{}".format(s_1))
s_template_2=Template("${x}thon is amazing!")
s_2=s_template_2.substitute(x="py")
print("s_2=s_template_2.substitute(x=\"py\")->{}".format(s_2))
s_template_3=Template("$x and $y AMAZING!")
substitute_dict=dict([('x','WANGDONG'),('y','NB')])
print("substitute_dict={}".format(substitute_dict))
s_3=s_template_3.substitute(substitute_dict)
print("s_3=s_template_3.substitute(substitute_dict)->{}".format(s_3))
# Out:
# s_1=s_template_1.substitute(x="NB")->NB,baoruiqin,NB!
# s_2=s_template_2.substitute(x="py")->python is amazing!
# substitute_dict={'x': 'WANGDONG', 'y': 'NB'}
# s_3=s_template_3.substitute(substitute_dict)->WANGDONG and NB AMAZING!

# %%
lst_s_3=list("包老师，给过吧!")
print("lst_s_3=list(\"包老师，给过吧!\")->{}".format(lst_s_3)) #"\" escape character
print("\"Hellow\"+\" Python!\"->{}".format("Hellow"+" Python!"))
print("\"+\".join(str(123456))->{}".format("+".join(str(123456))))
print("len(\"Hellow Python!\")->{}".format(len("Hellow Python!")))
coordinates="120.132007,30.300508,9.7"
print("coordinates.split(\",\")->{}".format(coordinates.split(",")))
print("eval(coordinates)->{}".format(eval(coordinates))) #通常用eval()方法将字符串，转换为对应数值形式；
print("\"包老师，给过吧!\".lower()->{}".format("包老师，给过吧!".lower()))
print("\"包老师，给过吧!\".upper()->{}".format("包老师，给过吧!".upper()))
print("\包老师，给过吧!\"[6:]->{}".format("包老师，给过吧"[6:]))
print("\"   包老师，给过吧   \".strip()->{}".format("    包老师，给过吧   ".strip()))
print("\"包老师，给过吧\".replace(\"Python\",\"Grasshopper\")->{}".format("包老师，给过吧".replace("Python","Grasshopper")))
hello_lst=list("包老师，给过吧")
hello_lst.sort()
print("hello_lst.sort()>{}".format(hello_lst))
print("\"包老师，给过吧\".find(\"Py\")->{}".format("呜呜呜呜呜呜呜".find("Py")))
# Out:
# lst_s_3=list("包老师，给过吧!")->['包', '老', '师', '，', '给', '过', '吧', '!']
# "Hellow"+" Python!"->Hellow Python!
# "+".join(str(123456))->1+2+3+4+5+6
# len("Hellow Python!")->14
# coordinates.split(",")->['120.132007', '30.300508', '9.7']
# eval(coordinates)->(120.132007, 30.300508, 9.7)
# "包老师，给过吧!".lower()->包老师，给过吧!
# "包老师，给过吧!".upper()->包老师，给过吧!
# \包老师，给过吧!"[6:]->吧
# "   包老师，给过吧   ".strip()->包老师，给过吧
# "包老师，给过吧".replace("Python","Grasshopper")->包老师，给过吧
# hello_lst.sort()>['包', '吧', '师', '给', '老', '过', '，']
# "包老师，给过吧".find("Py")->-1

# %%
format_str="你好,%s and %s!"
values=("专业课","派生")
new_str=format_str % values
print("new_str=format_str % values->{}".format(new_str))

format_str_2="Pi with three decimals:%.3f,and enter a value with percent sign:%.2f %%" #如果字符串里包含实际的%，则通过%%即两个百分号进行转义

from math import pi
new_str_2=format_str_2 % (pi,3.1415926)
print("new_str_2=format_str_2 % (pi,3.1415926)->{}".format(new_str_2))
# Out:
# new_str=format_str % values->你好,专业课 and 派生!
# new_str_2=format_str_2 % (pi,3.1415926)->Pi with three decimals:3.142,and enter a value with percent sign:3.14 %

# %%
from string import Template
s_template_1=Template("$x,brilliant,$x!")
s_1=s_template_1.substitute(x="Python")
print("s_1=s_template_1.substitute(x=\"Python\")->{}".format(s_1))
s_template_2=Template("${x}thon is brilliant!")
s_2=s_template_2.substitute(x="py")
print("s_2=s_template_2.substitute(x=\"py\")->{}".format(s_2))
s_template_3=Template("$x and $y are bothbrilliant!")
substitute_dict=dict([('x','Python'),('y','Grasshopper')])
print("substitute_dict={}".format(substitute_dict))
s_3=s_template_3.substitute(substitute_dict)
print("s_3=s_template_3.substitute(substitute_dict)->{}".format(s_3))
# Out:
# s_1=s_template_1.substitute(x="Python")->Python,brilliant,Python!
# s_2=s_template_2.substitute(x="py")->python is brilliant!
# substitute_dict={'x': 'Python', 'y': 'Grasshopper'}
# s_3=s_template_3.substitute(substitute_dict)->Python and Grasshopper are bothbrilliant!

# %%
lst_1=list(range(29,37,2))
print("lst_1={}".format(lst_1))
print("_"*50)
print("for i in lst_1:")
for i in lst_1:
    print(i)
print("for i in range(len(lst_1)):")
for i in range(len(lst_1)):
    print("idx={},val={}".format(i,lst_1[i]))
print("+"*50)   
dic_4=dict(a=1,b=8,c=6,d=4)
print("dic_4={}".format(dic_4))
print("_"*50)
print("for k in dic_4:")
for k in dic_4:
    print(k)
print("for k,v in dic_4.items():")
for k,v in dic_4.items():
    print("key={},val={}".format(k,v))
# Out:
# lst_1=[29, 31, 33, 35]
# __________________________________________________
# for i in lst_1:
# 29
# 31
# 33
# 35
# for i in range(len(lst_1)):
# idx=0,val=29
# idx=1,val=31
# idx=2,val=33
# idx=3,val=35
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# dic_4={'a': 1, 'b': 8, 'c': 6, 'd': 4}
# __________________________________________________
# for k in dic_4:
# a
# b
# c
# d
# for k,v in dic_4.items():
# key=a,val=1
# key=b,val=8
# key=c,val=6
# key=d,val=4

# %%
x=9
while x<=80000:
    print("x={}".format(x))
    x+=10 #增量赋值; x*=2
# Out:
# x=9
# x=19
# x=29
# x=39
# x=49
# x=59
# x=69
# x=79
# x=89
# x=99
# x=109
# x=119
# x=129
# x=139
# x=149
# x=159
# x=169
# x=179
# x=189
# x=199
# x=209
# x=219
# x=229
# x=239
# x=249
# x=259
# x=269
# x=279
# x=289
# x=299
# x=309
# x=319
# x=329
# x=339
# x=349
# x=359
# x=369
# x=379
# x=389
# x=399
# x=409
# x=419
# x=429
# x=439
# x=449
# x=459
# x=469
# x=479
# x=489
# x=499
# x=509
# x=519
# x=529
# x=78189
# x=78199
# x=78209
# x=78219
# x=78229
# x=78239
# x=78249
# x=78259
# x=78269
# x=78279
# x=78289
# x=78299
# x=78309
# x=78319
# x=78329
# x=78339
# x=78349
# x=78359
# x=78369
# x=78379
# x=78389
# x=78399
# x=78409
# x=78419
# x=78429
# x=78439
# x=78449
# x=78459
# x=78469
# x=78479
# x=78489
# x=78499
# x=78509
# x=78519
# x=78529
# x=78539
# x=78549
# x=78559
# x=78569
# x=78579
# x=78589
# x=78599
# x=78609
# x=78619
# x=78629
# x=78639
# x=78649
# x=78659
# x=78669
# x=78679
# x=78689
# x=78699
# x=78709
# x=78719
# x=78729
# x=78739
# x=78749
# x=78759
# x=78769
# x=78779
# x=78789
# x=78799
# x=78809
# x=78819
# x=78829
# x=78839
# x=78849
# x=78859
# x=78869
# x=78879
# x=78889
# x=78899
# x=78909
# x=78919
# x=78929
# x=78939
# x=78949
# x=78959
# x=78969
# x=78979
# x=78989
# x=78999
# x=79009
# x=79019
# x=79029
# x=79039
# x=79049
# x=79059
# x=79069
# x=79079
# x=79089
# x=79099
# x=79109
# x=79119
# x=79129
# x=79139
# x=79149
# x=79159
# x=79169
# x=79179
# x=79189
# x=79199
# x=79209
# x=79219
# x=79229
# x=79239
# x=79249
# x=79259
# x=79269
# x=79279
# x=79289
# x=79299
# x=79309
# x=79319
# x=79329
# x=79339
# x=79349
# x=79359
# x=79369
# x=79379
# x=79389
# x=79399
# x=79409
# x=79419
# x=79429
# x=79439
# x=79449
# x=79459
# x=79469
# x=79479
# x=79489
# x=79499
# x=79509
# x=79519
# x=79529
# x=79539
# x=79549
# x=79559
# x=79569
# x=79579
# x=79589
# x=79599
# x=79609
# x=79619
# x=79629
# x=79639
# x=79649
# x=79659
# x=79669
# x=79679
# x=79689
# x=79699
# x=79709
# x=79719
# x=79729
# x=79739
# x=79749
# x=79759
# x=79769
# x=79779
# x=79789
# x=79799
# x=79809
# x=79819
# x=79829
# x=79839
# x=79849
# x=79859
# x=79869
# x=79879
# x=79889
# x=79899
# x=79909
# x=79919
# x=79929
# x=79939
# x=79949
# x=79959
# x=79969
# x=79979
# x=79989
# x=79999

# %%
x=20000
while x<=66666666:
    print("x={}".format(x))
    x+=10 
    if x>=50:break    
    
import sys
print("sys.maxsize={}".format(sys.maxsize))
for i in range(sys.maxsize):
    print("i={}".format(i))  #?
    i+=10
    if i>=30:break
# Out:
# x=20000
# sys.maxsize=9223372036854775807
# i=0
# i=1
# i=2
# i=3
# i=4
# i=5
# i=6
# i=7
# i=8
# i=9
# i=10
# i=11
# i=12
# i=13
# i=14
# i=15
# i=16
# i=17
# i=18
# i=19
# i=20

# %%
lst_x=[0,1,2,3]
lst_y=['point_a','point_b','point_c','point_d']
zip_lst=zip(lst_x,lst_y) #The zip() function takes iterables (can be zero or more), aggregates them in a tuple, and returns it.
print("zip_lst=zip(lst_x,lst_y)->{}".format(zip_lst))
print("dict(zip_lst)->{}".format(dict(zip_lst)))

zip_lst=zip(lst_x,lst_y) #迭代对象临时存储，读取完后为空
for x,y in zip_lst:
    print(x,y)
    
zip_lst=zip(lst_x,lst_y)
x,y=zip(*zip_lst)
print("x={},y={}".format(x,y))
# Out:
# zip_lst=zip(lst_x,lst_y)-><zip object at 0x0000020E6A2D0140>
# dict(zip_lst)->{0: 'point_a', 1: 'point_b', 2: 'point_c', 3: 'point_d'}
# 0 point_a
# 1 point_b
# 2 point_c
# 3 point_d
# x=(0, 1, 2, 3),y=('point_a', 'point_b', 'point_c', 'point_d')

# %%
lst_bbb=['point_a','point_b','point_c','point_d']
dic_4={}
for idx,value in enumerate(lst_bbb):
    dic_4[idx]=value
print("dic_4={}".format(dic_4))
print("dict((i,v) for i,v in enumerate(lst_bbb))->{}".format(dict((i,v) for i,v in enumerate(lst_bbb)))) #list comprehension
print("_"*50)
for i,(a,b) in enumerate(zip(lst_a,lst_b)):
    print('%d:%s,%s'%(i,a,b))
# Out:
# dic_4={0: 'point_a', 1: 'point_b', 2: 'point_c', 3: 'point_d'}
# dict((i,v) for i,v in enumerate(lst_bbb))->{0: 'point_a', 1: 'point_b', 2: 'point_c', 3: 'point_d'}
# __________________________________________________
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8508/2016176845.py in <module>
#       6 print("dict((i,v) for i,v in enumerate(lst_bbb))->{}".format(dict((i,v) for i,v in enumerate(lst_bbb)))) #list comprehension
#       7 print("_"*50)
# ----> 8 for i,(a,b) in enumerate(zip(lst_a,lst_b)):
#       9     print('%d:%s,%s'%(i,a,b))
#
# NameError: name 'lst_a' is not defined

# %%
print("[x*x for x in range(98,37,12) if x%2==0]->{}".format([x*x for x in range(98,37,12) if x%2==0]))
print("[(x,y) for x in range(3)for y in range(2)]->{}".format([(x,y) for x in range(3)for y in range(2)]))
print("[(x,y) for x,y in zip(range(3),range(2))]->{}".format([(x,y) for x,y in zip(range(3),range(2))]))
nested_list=[[a for a in range(1,10,3)],2,3,[b for b in range(60,100,7)],[[c for c in range(1000,2000,120)],3,9]]
print("[[a for a in range(7,4,15)],2,3,[b for b in range(47,10,9)],[[c for c in range(100,200,20)],3,9]]->{}".format(nested_list)) #嵌套列表推导式

flatten_lst=lambda lst: [m for n_lst in lst for m in flatten_lst(n_lst)] if type(lst) is list else [lst] #展平列表常用，可以放置到单独的.py文件中调用。lambda函数后文阐述
print("flatten_lst(nested_list)->{}".format(flatten_lst(nested_list)))
# Out:
# [x*x for x in range(98,37,12) if x%2==0]->[]
# [(x,y) for x in range(3)for y in range(2)]->[(0, 0), (0, 1), (1, 0), (1, 1), (2, 0), (2, 1)]
# [(x,y) for x,y in zip(range(3),range(2))]->[(0, 0), (1, 1)]
# [[a for a in range(7,4,15)],2,3,[b for b in range(47,10,9)],[[c for c in range(100,200,20)],3,9]]->[[1, 4, 7], 2, 3, [60, 67, 74, 81, 88, 95], [[1000, 1120, 1240, 1360, 1480, 1600, 1720, 1840, 1960], 3, 9]]
# flatten_lst(nested_list)->[1, 4, 7, 2, 3, 60, 67, 74, 81, 88, 95, 1000, 1120, 1240, 1360, 1480, 1600, 1720, 1840, 1960, 3, 9]

# %%
x=10
if x<0:
    print('我不会挂科.')
elif x==0:
    print('我还是不会挂科')
    print('没想到吧')
else:
    print('包瑞清老师的学生永远不会挂科.')
# Out:
# 包瑞清老师的学生永远不会挂科.

# %%
x=y=[1,3,5]
z=[2,4,6]
print("x==y->{}".format(x==y))
print("x is y->{}".format(x is y))
print("x==z->{}".format(x==z))
print("x is z->{}".format(x is z))
print("x is not y->{}".format(x is not y))
print("x is not z->{}".format(x is not z))
print("id_x:{};id_y:{};id_z:{}".format(id(x),id(y),id(z))) #Memory Location

del x[2]
print("x={},y={},z={} after del x[2]".format(x,y,z))
# Out:
# x==y->True
# x is y->True
# x==z->False
# x is z->False
# x is not y->False
# x is not z->True
# id_x:2260934150272;id_y:2260934150272;id_z:2260934150912
# x=[1, 3],y=[1, 3],z=[2, 4, 6] after del x[2]

# %%
x=[48888,4523,583453]
print("48888 in x->{}".format(3 in x))
print("4523 in x->{}".format(0 in x))
print("583453 not in x->{}".format(3 not in x))
print("4523 not in x->{}".format(0 not in x))
# Out:
# 48888 in x->False
# 4523 in x->False
# 583453 not in x->True
# 4523 not in x->True

# %%
a,b,c=0,44,155
if c>a and c<b:
    print('a<c<b')
else: print('a<c<b wocaooooooooooo!!!')
# Out:
# a<c<b wocaooooooooooo!!!

# %%
def simple_func(a,b):
    a=pow(a,2)+b
    return z
print("simple_func(7,56)->{}".format(simple_func(3,7)))
print("simple_func(538,538)->{}".format(simple_func(7,3)))
print("simple_func(b=7,a=3)->{}".format(simple_func(b=7,a=3)))
# Out:
# simple_func(7,56)->[2, 4, 6]
# simple_func(538,538)->[2, 4, 6]
# simple_func(y=7,x=3)->[2, 4, 6]

# %%
def fibonacci(s,count): #定义fib函数的方法较笨
    fib_lst=[0,1]
    fib_part=[]
    if s==0 or s==1:
        fib_part[:]=fib_lst
        for i in range(count-2):
            fib_part.append(fib_part[-1]+fib_part[-2])
    else:
        while True:
            fib_lst[:]=[fib_lst[1],fib_lst[0]+fib_lst[1]]
            #print(fib_lst)
            if fib_lst[1]-s>=0:break
        fib_part[:]=fib_lst
        if abs(fib_lst[0]-s)>=abs(fib_lst[1]-s):
            for i in range(count-1):
                fib_part.append(fib_part[-1]+fib_part[-2])
            fib_part.pop(0)
        else:
            for i in range(count-2):
                fib_part.append(fib_part[-1]+fib_part[-2])
    return fib_part

print("fibonacci(6,9)->{}".format(fibonacci(6,9)))
print("fibonacci(7,9)->{}".format(fibonacci(7,9)))

# %%
class cat:
    run='yahoo' 
    def __init__(self):
        self.hungry=True
    def eat(self):
        if self.hungry:
            print('youhou')
            self.hungry=False
        else:
            print('geiwoligiaogiao!')
class Apodidae(cat):
    def __init__(self):
        super(Apodidae,self).__init__()
        self.sound='wolf!'
    def sing(self):
        print(self.sound)
swift=Apodidae()
print("swift.run->{}".format(swift.run))
print("swift.eat()->")
swift.eat()
print("swift.blow()->")
swift.eat()
print("swift.suck()->")
swift.sing()
blackswift=Apodidae()
scarceswift=Apodidae()
print("blackswift.sing()->")
blackswift.sing()
print("scarceswift.sing()->")
scarceswift.sing()
print("blackswift.run->{}".format(blackswift.run))
blackswift.run='humming'
print("blackswift.run after redefining the blackswif's attribute->{}".format(blackswift.run))
print("scarceswift.run->{}".format(scarceswift.run))
help(Apodidae)
help(cat)
print("_"*50)
# Out:
# swift.run->yahoo
# swift.eat()->
# youhou
# swift.blow()->
# geiwoligiaogiao!
# swift.suck()->
# wolf!
# blackswift.sing()->
# wolf!
# scarceswift.sing()->
# wolf!
# blackswift.run->yahoo
# blackswift.run after redefining the blackswif's attribute->humming
# scarceswift.run->yahoo
# Help on class Apodidae in module __main__:
#
# class Apodidae(cat)
#  |  Method resolution order:
#  |      Apodidae
#  |      cat
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  sing(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from cat:
#  |
#  |  eat(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from cat:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from cat:
#  |
#  |  run = 'yahoo'
#
# Help on class cat in module __main__:
#
# class cat(builtins.object)
#  |  Methods defined here:
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  eat(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  run = 'yahoo'
#
# __________________________________________________

# %%
class Fibs():
    def __init__(self):
        self.a=0
        self.b=1
    def next(self):  #实现迭代器的next方法
        self.a,self.b=self.b,self.a+self.b
        return self.a
    def __iter__(self): #实现迭代方法
        return self

# %%
lst_e=[list(range(9,50,80)),[80,7,67,list(range(5)),89]]
print("lst_e={}".format(lst_e))
print("_"*50)
flatten_lst=[]
for v_1 in lst_e:
    try:
        for v_2 in v_1:
            try:
                for v_3 in v_2:
                    flatten_lst.append(v_3)
            except TypeError:
                flatten_lst.append(v_2)
    except TypeError:
        flatten_lst.append(v_1)
print("flatten_lst={}".format(flatten_lst))
# Out:
# lst_e=[[9], [80, 7, 67, [0, 1, 2, 3, 4], 89]]
# __________________________________________________
# flatten_lst=[9, 80, 7, 67, 0, 1, 2, 3, 4, 89]

# %%
def flatten(lst):
    try:       
        for n_lst in lst:         
            for m in flatten(n_lst):           
                yield m  
    except TypeError: 
        yield lst 
print("list(flatten(lst_e))->{}".format(list(flatten(lst_e))))
# Out:
# list(flatten(lst_e))->[9, 80, 7, 67, 0, 1, 2, 3, 4, 89]

# %%
def infinite():
    n=0
    while True:
        yield 'num#'+str(n)
        n+=666
n=infinite()
print("next(n)->{}".format(next(n)))
print("next(n)->{}".format(next(n)))
print("next(n)->{}".format(next(n)))
print("[next(n) for i in range(5)]->{}".format([next(n) for i in range(5)]))
# Out:
# next(n)->num#0
# next(n)->num#666
# next(n)->num#1332
# [next(n) for i in range(5)]->['num#1998', 'num#2664', 'num#3330', 'num#3996', 'num#4662']

# %%
n=9999
print("[[(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n)]->{}".format([[(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n)]))
print("_"*50)
print("([(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n))->{}".format(([(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n))))
gen=([(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n))
print("next(gen)->{}".format(next(gen)))
print("next(gen)->{}".format(next(gen)))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8508/2771327277.py in <module>
#       1 n=9999
# ----> 2 print("[[(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n)]->{}".format([[(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n)]))
#       3 print("_"*50)
#       4 print("([(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n))->{}".format(([(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n))))
#       5 gen=([(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n))
#
# ~\AppData\Local\Temp/ipykernel_8508/2771327277.py in <listcomp>(.0)
#       1 n=9999
# ----> 2 print("[[(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n)]->{}".format([[(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n)]))
#       3 print("_"*50)
#       4 print("([(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n))->{}".format(([(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n))))
#       5 gen=([(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n))
#
# ~\AppData\Local\Temp/ipykernel_8508/2771327277.py in <listcomp>(.0)
#       1 n=9999
# ----> 2 print("[[(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n)]->{}".format([[(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n)]))
#       3 print("_"*50)
#       4 print("([(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n))->{}".format(([(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n))))
#       5 gen=([(2*pi*(2*(u/(n-1))-1),2*pi*(2*(v/(n-1))-1)) for u in range(n)] for v in range(n))
#
# MemoryError:

# %%
try:
    do something
except:
    do something
Copy to clipboardErrorCopied
def f_convert_a(x):
    try:
        return float(x)
    except:
        return x
print("f_convert_a('3.1415')->{}".format(f_convert_a('3.1415')))    
print("f_convert_a('string')->{}".format(f_convert_a('string')))  
print("f_convert_a(3,6,7)->{}".format(f_convert_a((3,6,7))))
# Out:
#   File "C:\Users\Dell\AppData\Local\Temp/ipykernel_8508/3542311816.py", line 2
#     do something
#        ^
# SyntaxError: invalid syntax

# %%
def f_open_b(fp):
    try:
        f=open(fp,'r')
    except IOError as e:
        print('Unable to open',fp,':%s\n' %e)
    else:
        data=f.read()
        f.close()
        return data
    finally:
        print('done!')
f_open_b("./data/tryException.txt")
# Out:
# Unable to open ./data/tryException.txt :[Errno 2] No such file or directory: './data/tryException.txt'
#
# done!
